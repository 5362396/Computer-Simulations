# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Zad. 1. Narysować trójkąt o wierzchołkach w punktach: (0,0), (10, 1), (5,7).

# %%
x = [0, 10, 5]
y = [0, 1, 7]

triangle = plt.Polygon(np.column_stack((x, y)), facecolor='red', edgecolor='black')

ax = plt.gca()
ax.add_patch(triangle)

plt.xlim(0, 11)
plt.ylim(0, 8)
plt.show()

# %% [markdown]
# Zad. 2. Narysować na jednym wykresie trzy funkcje, zgodnie z poniższym opisem
# • f(x) = cosx — kolor czerwony, linia kropkowana,
# • g(x) = cos2x — kolor niebieski, linia ciągła,
# • h(x) = cos3x — kolor zielony, linia kreskowana,
# w przedziale [0,2π]. Opisać osie wykresu, dodać legendę oraz włączyć wyświetlanie siatki pomocniczej.

# %%
x = np.linspace(0, 2*math.pi, 400)
f = np.cos(x)
g = np.cos(x) ** 2
h = np.cos(x) ** 3

plt.plot(x, f, 'r:')
plt.plot(x, g, 'b-')
plt.plot(x, h, 'g--')
plt.show()

# %% [markdown]
# Zad. 3. Narysować dwa wykresy funkcji y = cos(10·ex) w przedziale [−2,2]. Wykresy umieścić jeden pod drugim, dzieląc okno graficzne na dwie części. Do przygotowania danych do wykonania pierwszego wykresu zastosować funkcję fplot, natomiast do drugiego — 100 równomiernie rozłożonych punktów w podanym przedziale. Oba wykresy narysować funkcją plot. Z czego wynikają różnice pomiędzy wykresami?

# %%
from matplotlib import gridspec

fig = plt.figure()
gs = gridspec.GridSpec(2, 2)
